# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
df= pd.read_csv("tweet_replies2.csv")

# %%
df.head()
# Out:
#            User                                               Text  \
# 0   @BarisUnver  700 bin lira bütçeye uygun en dertsiz aile ara...
# 1   @anumariiii  Aga her modele bi  cevabın var ama nedense diy...
# 2   @BarisUnver  Vallahi anlamıyorum ya, verdiğin cevaplarda bi...
# 3  @turistikoda      Ne fakirsin 700 ü ben bazen ayda kazanıyorum.
# 4   @BarisUnver  Allah sana daha çok versin, yapacak bir şey yo...
#
#                        Date
# 0  2025-12-26T06:33:05.000Z
# 1  2025-12-26T20:53:14.000Z
# 2  2025-12-26T21:10:03.000Z
# 3  2025-12-26T20:57:29.000Z
# 4  2025-12-26T21:12:59.000Z

# %%
df.tail()
# Out:
#                  User                                               Text  \
# 345    @urulusoy_ugur                 Mitsubishi kanser 1.6 köpek balığı
# 346  @gelecekicinuret                        El arabası yada at arabası
# 347         @ergunkrt          Edirne'den çıkınca bunları alabilirsiniz.
# 348  @iamyourfather89  Pejo 301 ve Citroen c elysee 1.6 hdi veya 1.6 ...
# 349      @mit57730385                                     Toyota Corolla
#
#                          Date
# 345  2025-12-26T22:49:04.000Z
# 346  2025-12-26T20:40:01.000Z
# 347  2025-12-26T23:23:19.000Z
# 348  2025-12-26T21:58:09.000Z
# 349  2025-12-26T22:38:29.000Z

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   User    350 non-null    object
#  1   Text    350 non-null    object
#  2   Date    350 non-null    object
# dtypes: object(3)
# memory usage: 8.3+ KB

# %%
df.isna().sum()
# Out:
# User    0
# Text    0
# Date    0
# dtype: int64

# %%
df = df.drop("Date", axis = 1)

# %%
df.head()
# Out:
#            User                                               Text
# 0   @BarisUnver  700 bin lira bütçeye uygun en dertsiz aile ara...
# 1   @anumariiii  Aga her modele bi  cevabın var ama nedense diy...
# 2   @BarisUnver  Vallahi anlamıyorum ya, verdiğin cevaplarda bi...
# 3  @turistikoda      Ne fakirsin 700 ü ben bazen ayda kazanıyorum.
# 4   @BarisUnver  Allah sana daha çok versin, yapacak bir şey yo...

# %%
i = df[df.User == "@BarisUnver"].index
df.drop(i, inplace = True)

# %%
df.drop("User", axis = 1, inplace = True)

# %%
df
# Out:
#                                                   Text
# 1    Aga her modele bi  cevabın var ama nedense diy...
# 3        Ne fakirsin 700 ü ben bazen ayda kazanıyorum.
# 5    Hyundai i20  birde tüplü oldu mu dadından yenm...
# 6                                                 Clio
# 7                          O paralara araba var mı ya
# ..                                                 ...
# 345                 Mitsubishi kanser 1.6 köpek balığı
# 346                        El arabası yada at arabası
# 347          Edirne'den çıkınca bunları alabilirsiniz.
# 348  Pejo 301 ve Citroen c elysee 1.6 hdi veya 1.6 ...
# 349                                     Toyota Corolla
#
# [347 rows x 1 columns]

# %%
from transformers import pipeline

# %%
analyzer = pipeline("sentiment-analysis", model="savasy/bert-base-turkish-sentiment-cased")
# Out:
# Device set to use cpu

# %%
car_dict = [
    "fiat", "egea", "doblo", "fiorino",
    "renault", "clio", "megane", "taliant", "austral",
    "togg", "t10x",    "honda", "civic", "city", "cr-v",
    "toyota", "corolla", "yaris", "c-hr",
    "ford", "focus", "fiesta", "puma", "kuga", "ranger",
    "peugeot", "208", "3008", "2008", "408",
    "opel", "corsa", "astra", "mokka",
    "volkswagen", "vw", "polo", "golf", "passat", "tiguan", "t-roc",
    "hyundai", "i20", "i10", "tucson", "bayon",
    "citroen", "c3", "c4", "c5","dacia", "duster", "sandero",
    "chery", "omoda", "tiggo","mercedes", "bmw", "audi", "volvo", "kia",
    "mitsubishi", "fluence", "mazda","skoda", "courier" "accent blue"
]

# %%
def marka_tespit(text):
    text = text.lower()
    detected = []
    for arac in car_dict:
        if arac in text:
            detected.append(arac)
    return detected[0] if detected else None

# %%
def sentiment_analyzing(text):
    """Cümlenin duygu durumunu ve skorunu döndürür."""
    if len(text.split()) == 1:
            etiket = "pozitif"
    else:
        sonuc = analyzer(text)[0]
    # Model 'positive'/'negative' döndürür. Biz bunu Türkçe'ye çevirelim.
        etiket = "pozitif" if sonuc['label'] == 'positive' else "negatif"
    return etiket

# %%
df['tespit_edilen_arac'] = df['Text'].apply(marka_tespit)

# %%
df["class"] = df["Text"].apply(sentiment_analyzing)

# %%
positive_df = df[df["class"] == "pozitif"]

# %%
positive_df
# Out:
#                                                   Text tespit_edilen_arac  \
# 1    Aga her modele bi  cevabın var ama nedense diy...               None
# 5    Hyundai i20  birde tüplü oldu mu dadından yenm...            hyundai
# 6                                                 Clio               clio
# 15   Toyota,Honda ve Hyundainin 700 bin TL ye satıl...              honda
# 18   Kia ceed 2011 kullanıyorum; içi geniş, otomati...                kia
# ..                                                 ...                ...
# 339  Bu ülkede o 500.000-1.500.000 TL aralığında al...               egea
# 340  Hyundai Elantra (2010-2015), 1.6 benzin otomat...            hyundai
# 341  Toyota 1.4 d alıp temizinden arkana yaslanacak...             toyota
# 342                                            Hyundai            hyundai
# 349                                     Toyota Corolla             toyota
#
#        class
# 1    pozitif
# 5    pozitif
# 6    pozitif
# 15   pozitif
# ...

# %%
pos_sonuc_tablosu = positive_df["tespit_edilen_arac"].value_counts().reset_index()

# %%
pos_sonuc_tablosu
# Out:
#    tespit_edilen_arac  count
# 0              toyota     16
# 1                egea     11
# 2               honda     10
# 3             corolla      9
# 4             hyundai      8
# 5                fiat      5
# 6                ford      5
# 7                clio      4
# 8             renault      4
# 9                polo      3
# 10            fluence      3
# 11              mazda      2
# 12            citroen      2
# 13            peugeot      2
# 14                kia      1
# 15              dacia      1
# 16         volkswagen      1
# 17                 c4      1
# 18             passat      1
# 19               2008      1
# 20         mitsubishi      1
# 21            taliant      1
# 22              volvo      1
# 23              doblo      1
# 24             duster      1
# 25           mercedes      1
# 26             megane      1
# 27             fiesta      1

# %%
negative_df = df[df["class"] == "negatif"]

# %%
negative_df
# Out:
#                                                   Text tespit_edilen_arac  \
# 3        Ne fakirsin 700 ü ben bazen ayda kazanıyorum.               None
# 7                          O paralara araba var mı ya                None
# 8    2018-2019 Fiat Egea Easy paket 1.6 Multijet Ot...               fiat
# 9    Egea, 301, celysee düşük km orta paket temiz s...               egea
# 10   Corolla 1.6/1.33  Fluence 1.5 dci C elyse / 30...               egea
# ..                                                 ...                ...
# 344                               Herhangi bir Corolla            corolla
# 345                 Mitsubishi kanser 1.6 köpek balığı         mitsubishi
# 346                        El arabası yada at arabası                None
# 347          Edirne'den çıkınca bunları alabilirsiniz.               None
# 348  Pejo 301 ve Citroen c elysee 1.6 hdi veya 1.6 ...            citroen
#
#        class
# 3    negatif
# 7    negatif
# 8    negatif
# 9    negatif
# ...

# %%
neg_sonuc_tablosu = negative_df["tespit_edilen_arac"].value_counts().reset_index()

# %%
neg_sonuc_tablosu
# Out:
#    tespit_edilen_arac  count
# 0                egea     25
# 1              toyota     16
# 2                clio     15
# 3             corolla     15
# 4               honda     14
# 5                fiat     13
# 6             hyundai      7
# 7               skoda      6
# 8             renault      5
# 9              megane      5
# 10               ford      5
# 11               opel      4
# 12            citroen      3
# 13         mitsubishi      3
# 14              astra      3
# 15                i20      3
# 16                kia      2
# 17              civic      2
# 18              mazda      2
# 19         volkswagen      1
# 20            taliant      1
# 21                bmw      1
# 22              focus      1
# 23               2008      1
# 24            fluence      1
# 25              doblo      1
# 26             fiesta      1
# 27               golf      1
# 28            fiorino      1
# 29           mercedes      1

# %%
df_empty = df[df["tespit_edilen_arac"].isna()].reset_index()

# %%
df_empty
# Out:
#     index                                               Text  \
# 0       1  Aga her modele bi  cevabın var ama nedense diy...
# 1       3      Ne fakirsin 700 ü ben bazen ayda kazanıyorum.
# 2       7                        O paralara araba var mı ya
# 3      21  manuel dizel accent blue km düşük olmasına dik...
# 4      24                       kazalı belalı çakal kasa e46
# ..    ...                                                ...
# 85    322  700K araç alıyorsanız, sadede expertiz değil a...
# 86    325         courier tabiki 3 tane aldık taş gibi araba
# 87    331  Valla dertsiz ve aile arabası diyorsan. Temiz ...
# 88    346                        El arabası yada at arabası
# 89    347          Edirne'den çıkınca bunları alabilirsiniz.
#
#    tespit_edilen_arac    class
# 0                None  pozitif
# 1                None  negatif
# 2                None  negatif
# 3                None  pozitif
# 4                None  negatif
# ..                ...      ...
# ...

# %%
df_empty.to_csv("emptydata.csv")

# %%
positive_df.reset_index(inplace=True)

# %%
i = positive_df[positive_df["tespit_edilen_arac"].isna()].index

# %%
i
# Out:
# Index([  0,   6,   9,  10,  13,  15,  19,  20,  29,  36,  43,  48,  52,  54,
#         55,  57,  60,  64,  68,  69,  71,  73,  84,  90,  97, 100, 102, 104,
#        105, 107, 108, 112, 114, 115, 116, 120, 122, 123, 124, 128],
#       dtype='int64')

# %%
positive_df.drop(i,axis = 0,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19868\1712382625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_df.drop(i,axis = 0,inplace=True)

# %%
positive_df
# Out:
#      index                                               Text  \
# 1        5  Hyundai i20  birde tüplü oldu mu dadından yenm...
# 2        6                                               Clio
# 3       15  Toyota,Honda ve Hyundainin 700 bin TL ye satıl...
# 4       18  Kia ceed 2011 kullanıyorum; içi geniş, otomati...
# 5       20     Ford focus sedan abi 10 senede tek arızası yok
# ..     ...                                                ...
# 133    339  Bu ülkede o 500.000-1.500.000 TL aralığında al...
# 134    340  Hyundai Elantra (2010-2015), 1.6 benzin otomat...
# 135    341  Toyota 1.4 d alıp temizinden arkana yaslanacak...
# 136    342                                            Hyundai
# 137    349                                     Toyota Corolla
#
#     tespit_edilen_arac    class
# 1              hyundai  pozitif
# 2                 clio  pozitif
# 3                honda  pozitif
# 4                  kia  pozitif
# 5                 ford  pozitif
# ...

# %%
positive_df["tespit_edilen_arac"].value_counts()
# Out:
# tespit_edilen_arac
# toyota        16
# egea          11
# honda         10
# corolla        9
# hyundai        8
# fiat           5
# ford           5
# clio           4
# renault        4
# polo           3
# fluence        3
# mazda          2
# citroen        2
# peugeot        2
# kia            1
# dacia          1
# volkswagen     1
# c4             1
# passat         1
# 2008           1
# mitsubishi     1
# taliant        1
# volvo          1
# doblo          1
# duster         1
# mercedes       1
# megane         1
# fiesta         1
# Name: count, dtype: int64

# %%
valuable_car = positive_df[positive_df["tespit_edilen_arac"] == "toyota"]

# %%
valuable_car.reset_index()
# Out:
#     level_0  index                                               Text  \
# 0        28     72                                    Toyota al reyis
# 1        32     82                                             Toyota
# 2        39    100                                     Toyota corolla
# 3        40    101          Toyota corolla 1.33  al kafan rahat etsin
# 4        42    108  Hiç düşünmeyin  Toyota diyenlere sizde katılın...
# 5        45    123            12-13-14 toyota corolla dertsiz tasasız
# 6        56    155                                     Toyota corolla
# 7        77    206  Kendim kullandım gerçekten toyota corolla çok ...
# 8        78    208                                2015 Toyota corolla
# 9        79    209  Herhangi x lira bütçeye uygun dertsiz araba he...
# 10       91    234                                     Toyota Corolla
# 11      117    285  Büyük ihtimalle 10 yaş altı olacak , o yüzden ...
# ...

# %%
twovaluable_car = positive_df[positive_df["tespit_edilen_arac"] == "egea"]

# %%
twovaluable_car
# Out:
#      index                                               Text  \
# 8       27  Sorunun cevabı belli kesinlikle Egea. Alabilec...
# 12      36                                               Egea
# 16      43  2015-2018 arası Egea 1.3 m.jet al. 1 milyon km...
# 24      63  Egea 1.6 e-torq  - Aisin marka sorunsuz japon ...
# 26      68  6 yıl 2017 model easy (bos paket) 1.3 egea kul...
# 59     167                                               Egea
# 75     202  Egea al dostum. 3 ay önce finansal açıdan raha...
# 80     213  Corolla Için söylenecek söz yok! Ama aile işin...
# 89     229  Eğer cok fazla özellik otomatik istemiyorsan e...
# 94     242                                               Egea
# 133    339  Bu ülkede o 500.000-1.500.000 TL aralığında al...
#
#     tespit_edilen_arac    class
# 8                 egea  pozitif
# 12                egea  pozitif
# 16                egea  pozitif
# 24                egea  pozitif
# 26                egea  pozitif
# ...
